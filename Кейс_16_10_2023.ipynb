# %% [markdown]
# # Кейс: удержание клиентов магазина
#
# К вам приходит руководитель продукта “Интернет-магазин Ascent” и спрашивает про удержание клиентов. У него есть опасение, что из-за проблем с доставкой товаров в магазине у нас стали больше оттекать пользователи
#
# Он просит вас сравнить, на сколько сейчас все хуже, чем в прошлых годах?
#
# Данные:
#
# * есть транзакции (покупки) в интернет магазине, в том числе id клиента, id покупки, timestamp покупки и тп
# * orders.csv, customers.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### 1. Загрузка данных:

# %%
customers = pd.read_csv('https://raw.githubusercontent.com/daeronel-data/data/main/customers.csv')
customers.head(3)
# Out:
#          id             name    segment       state             city
# 0  CG-12520      Claire Gute   Consumer    Kentucky        Henderson
# 1  DV-13045  Darrin Van Huff  Corporate  California      Los Angeles
# 2  SO-20335   Sean O'Donnell   Consumer     Florida  Fort Lauderdale

# %%
orders = pd.read_csv('https://raw.githubusercontent.com/daeronel-data/data/main/orders.csv')
orders.head(3)
# Out:
#        id  order_date ship_mode customer_id    sales
# 0  100006  2014-09-07  Standard    DK-13375  377.970
# 1  100090  2014-07-08  Standard    EB-13705  699.192
# 2  100293  2014-03-14  Standard    NF-18475   91.056

# %% [markdown]
# Сперва посмотрим на клиентские данные: можно также делить клиентов на когорты по сегментам.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 6), sharey=True)

sns.histplot(customers, x = 'segment', ax=ax1)
ax1.set_title('Распределение клиентов по сегменту')

sns.histplot(orders, x = 'ship_mode', ax=ax2)
ax2.set_title('Распределение заказов по типу доставки')

plt.show()

# %% [markdown]
# Теперь посмотрим на данные по заказам:
#
# На график нанесем скользящее среднее за 7 дней: для каждого дня считается среднее значение за предыдущие 7 дней)

# %%
plt.figure(figsize = (10,5))
dates = orders.groupby('order_date').count()['customer_id']
dates.plot(alpha = 0.4, label = 'Count orders')
dates.rolling(7).mean().plot(label = 'Rolling mean (week)') # код для расчета скользящего среднего, параметр в скобках - количество дней, по которым усредняем
plt.title('Распределение количества заказов по датам')
plt.xlabel('Дата заказа')
plt.legend()
plt.show()

# %% [markdown]
# * В данных явно видна сезонность по годам и месяцам

# %% [markdown]
# Статистики для суммы заказов
#
# В качестве параметра можно передать список нужных перцентилей:
# Например `percentiles=[.01, 0.99]`

# %% [markdown]
# ~ - отрицание логического условия

# %%
orders['sales'].describe(percentiles=[0.01, 0.99]).index
# Out:
# Index(['count', 'mean', 'std', 'min', '1%', '50%', '99%', 'max'], dtype='object')

# %%
orders['sales'].describe(percentiles=[0.01, 0.99]).to_frame().T
# Out:
#         count        mean         std    min       1%     50%         99%  \
# sales  5009.0  458.614666  954.730953  0.556  2.89688  151.96  4209.01448
#
#              max
# sales  23661.228

# %%
orders.head()
# Out:
#        id  order_date ship_mode customer_id    sales
# 0  100006  2014-09-07  Standard    DK-13375  377.970
# 1  100090  2014-07-08  Standard    EB-13705  699.192
# 2  100293  2014-03-14  Standard    NF-18475   91.056
# 3  100328  2014-01-28  Standard    JC-15340    3.928
# 4  100363  2014-04-08  Standard    JM-15655   21.376

# %%
orders.loc[orders['sales'] < 420]
# Out:
#           id  order_date ship_mode customer_id    sales
# 0     100006  2014-09-07  Standard    DK-13375  377.970
# 2     100293  2014-03-14  Standard    NF-18475   91.056
# 3     100328  2014-01-28  Standard    JC-15340    3.928
# 4     100363  2014-04-08  Standard    JM-15655   21.376
# 5     100391  2014-05-25  Standard    BW-11065   14.620
# ...      ...         ...       ...         ...      ...
# 5003  168690  2017-01-07  Standard    TS-21085    2.808
# 5004  168802  2017-11-03  Standard    JO-15145   18.368
# 5005  169320  2017-07-23    Second    LH-16900  171.430
# 5006  169488  2017-09-07     First    AA-10375   56.860
# 5007  169502  2017-08-28  Standard    MG-17650  113.410
#
# [3536 rows x 5 columns]

# %%
orders.loc[~((orders['ship_mode'] == 'Standard')|(orders['sales'] < 300))]
# Out:
#           id  order_date ship_mode customer_id     sales
# 23    101560  2014-11-28    Second    CS-12250   542.340
# 24    101602  2014-12-15     First    MC-18100   803.960
# 27    101931  2014-10-28     First    TS-21370  1252.602
# 37    102988  2014-04-05    Second    GM-14695  4251.920
# 40    103100  2014-12-20     First    AB-10105  1107.660
# ...      ...         ...       ...         ...       ...
# 4993  166324  2017-04-20     First    BE-11455   979.626
# 4998  167402  2017-01-13    Second    CP-12085  4619.330
# 5000  167920  2017-12-09    Second    JL-15835  1827.510
# 5001  168116  2017-11-04  Same Day    GT-14635  8167.420
# 5008  169551  2017-07-07     First    RL-19615  1344.838
#
# [739 rows x 5 columns]

# %% [markdown]
# ### Исследование данных по клиентам

# %% [markdown]
# Необходимо разделить пользователей на когорты.
# * Временем прихода клиента будем считать дату первого заказа.
# * Ушедшим клиентом будем считать такого, который сделал последний заказ год или больше назад.

# %% [markdown]
# Для каждого клиента посчитаем даты первого и последнего заказа, а также средний чек и количество заказов.

# %% [markdown]
# **Агрегация по нескольким столбцам и функциям**.
#
# В pandas можно делать агрегации сразу по нескольким столбцам и функциям. Для этого используется следующий синтаксис:
#
# `df.groupby([список столбцов, по которым группируем]).agg(словарь с нужными агрегациями)`
#
# Словарь с аггрегациями выглядит так:
# ```
# {'столбец1 (для которого хотим рассчитать значение' : [список агрегирующих функций],
# ...,
# 'столбецN (для которой хотим рассчитать значение' : [список агрегирующих функций]}
# ```

# %%
orders.groupby('customer_id').agg({'order_date': ['min', 'max']})
# Out:
#              order_date
#                     min         max
# customer_id
# AA-10315     2014-03-31  2017-06-29
# AA-10375     2014-04-21  2017-12-11
# AA-10480     2014-05-04  2017-04-15
# AA-10645     2014-06-22  2017-11-05
# AB-10015     2014-02-18  2016-11-10
# ...                 ...         ...
# XP-21865     2014-01-20  2017-11-17
# YC-21895     2014-11-17  2017-12-26
# YS-21880     2015-01-12  2017-12-21
# ZC-21910     2014-10-13  2017-11-06
# ZD-21925     2014-08-27  2017-06-11
#
# [793 rows x 2 columns]

# %%
agg_dict = {'order_date' : ['min', 'max'],
    'sales' : ['mean', 'count']
}

# %%
info = orders.groupby('customer_id').agg(agg_dict)
info.head()
# Out:
#              order_date                    sales
#                     min         max         mean count
# customer_id
# AA-10315     2014-03-31  2017-06-29  1112.712000     5
# AA-10375     2014-04-21  2017-12-11   117.376667     9
# AA-10480     2014-05-04  2017-04-15   447.628000     4
# AA-10645     2014-06-22  2017-11-05   847.822500     6
# AB-10015     2014-02-18  2016-11-10   295.385333     3

# %%
info.columns
# Out:
# MultiIndex([('order_date',   'min'),
#             ('order_date',   'max'),
#             (     'sales',  'mean'),
#             (     'sales', 'count')],
#            )

# %%
info.columns = ['min_order_date', 'max_order_date', 'mean_sales', 'count_sales']

# %%
info
# Out:
#             min_order_date max_order_date   mean_sales  count_sales
# customer_id
# AA-10315        2014-03-31     2017-06-29  1112.712000            5
# AA-10375        2014-04-21     2017-12-11   117.376667            9
# AA-10480        2014-05-04     2017-04-15   447.628000            4
# AA-10645        2014-06-22     2017-11-05   847.822500            6
# AB-10015        2014-02-18     2016-11-10   295.385333            3
# ...                    ...            ...          ...          ...
# XP-21865        2014-01-20     2017-11-17   215.878000           11
# YC-21895        2014-11-17     2017-12-26  1090.870000            5
# YS-21880        2015-01-12     2017-12-21   840.055500            8
# ZC-21910        2014-10-13     2017-11-06   617.362077           13
# ZD-21925        2014-08-27     2017-06-11   298.788800            5
#
# [793 rows x 4 columns]

# %% [markdown]
# **Переименование столбцов по отдельности**

# %%
# info = info.rename(columns={'min_order_date': 'min_date'})

# %% [markdown]
# **Объединение датафреймов**
#
# Для объединения датафреймов используется метод merge. Он имеет такой синтаксис:
#
# ```
# левая_таблица.merge(правая_таблица,
#                   left_on = столбец по которому соединяем из левой таблицы,
#                   right_on = столбец по которому соединяем из правой таблицы,
#                   how = тип соединения)
#
# ```
#
# Подробнее о параметрах можно почитать [в документации](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html).
#
#
# Для большего понимания: код в следующей ячейке аналогичен SQL выражению:
#
# `customer c LEFT JOIN info i ON c.id = i.customer_id `

# %%
customers_info = customers.merge(info, left_on = 'id', right_on = 'customer_id', how = 'left')

# %%
customers_info
# Out:
#            id               name      segment           state  \
# 0    CG-12520        Claire Gute     Consumer        Kentucky
# 1    DV-13045    Darrin Van Huff    Corporate      California
# 2    SO-20335     Sean O'Donnell     Consumer         Florida
# 3    BH-11710    Brosina Hoffman     Consumer      California
# 4    AA-10480       Andrew Allen     Consumer  North Carolina
# ..        ...                ...          ...             ...
# 788  CJ-11875       Carl Jackson    Corporate    Pennsylvania
# 789  RS-19870         Roy Skaria  Home Office            Iowa
# 790  SC-20845         Sung Chung     Consumer        Illinois
# 791  RE-19405    Ricardo Emerson     Consumer            Ohio
# 792  SM-20905  Susan MacKendrick     Consumer            Ohio
#
#                   city min_order_date max_order_date   mean_sales  \
# 0            Henderson     2015-10-15     2017-01-26   382.926667
# 1          Los Angeles     2016-06-12     2017-12-11   223.896600
# 2      Fort Lauderdale     2015-10-11     2017-12-01   433.762583
# 3          Los Angeles     2014-06-09     2017-12-07   781.918875
# 4              Concord     2014-05-04     2017-04-15   447.628000
# ..                 ...            ...            ...          ...
# 788       Philadelphia     2016-12-30     2016-12-30    16.520000
# 789         Burlington     2016-06-07     2017-12-11    11.164000
# 790  Arlington Heights     2016-11-11     2017-08-21   140.316000
# 791               Kent     2014-12-29     2014-12-29    48.360000
# 792             Newark     2016-05-03     2016-05-03  1043.041000
#
#      count_sales cohort_month
# 0              3      2015-10
# 1              5      2016-06
# 2              6      2015-10
# 3              8      2014-06
# 4              4      2014-05
# ..           ...          ...
# 788            1      2016-12
# 789            2      2016-06
# 790            2      2016-11
# 791            1      2014-12
# 792            1      2016-05
#
# [793 rows x 10 columns]

# %% [markdown]
# Для работы с датами удобно перевести столбец в формат datetime ([статья](https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587) на английском для желающих погрузиться глубже.

# %%
customers_info['cohort_month'] = pd.to_datetime(customers_info['min_order_date'], infer_datetime_format=True).dt.strftime('%Y-%m')

# %%
customers_info['cohort_year'] = pd.to_datetime(customers_info['min_order_date'], infer_datetime_format=True).dt.year

# %%
customers_info.head()
# Out:
#          id             name    segment           state             city  \
# 0  CG-12520      Claire Gute   Consumer        Kentucky        Henderson
# 1  DV-13045  Darrin Van Huff  Corporate      California      Los Angeles
# 2  SO-20335   Sean O'Donnell   Consumer         Florida  Fort Lauderdale
# 3  BH-11710  Brosina Hoffman   Consumer      California      Los Angeles
# 4  AA-10480     Andrew Allen   Consumer  North Carolina          Concord
#
#   min_order_date max_order_date  mean_sales  count_sales cohort_month  \
# 0     2015-10-15     2017-01-26  382.926667            3      2015-10
# 1     2016-06-12     2017-12-11  223.896600            5      2016-06
# 2     2015-10-11     2017-12-01  433.762583            6      2015-10
# 3     2014-06-09     2017-12-07  781.918875            8      2014-06
# 4     2014-05-04     2017-04-15  447.628000            4      2014-05
#
#    cohort_year
# 0         2015
# 1         2016
# 2         2015
# 3         2014
# 4         2014

# %% [markdown]
# Посмотрим, когда к нам приходили клиенты (распределение по когортам):

# %%
customers_info.groupby('cohort_month').count()['id'].plot.bar(alpha = 0.5, figsize = (10, 5))
plt.title('Количество новых клиентов за месяц')
plt.grid(axis='y')
plt.xlabel('Месяц когорты')
plt.show()

# %% [markdown]
# **Подписи к столбцам на графике**
#
# Пример кода ниже. Что важно помнить:
#
# `rects = ax.patches` - тут хранятся координаты
# `labels = df_year.values` - список со значениями, которыми будем подписывать, из нашего датафрейма
#
# Подписывать будем с помощью метода ax.text, разберем подробнее его параметры:
#
# `ax.text(`
#   `rect.get_x() + rect.get_width()` / 2, - координата середины столбца.
#   `height + 3`, - высота столбца + отступ (чтобы текст не сливался со столбцом), отступ можно менять.
#   `label`, - подпись.
#   `ha="center"`, - выравнивание текста по вертикали по центру.
#   `va="bottom"` - выравнивание текста по вертикали к низу)

# %%
df_year = customers_info.groupby('cohort_year').count()['mean_sales']
df_year
# Out:
# cohort_year
# 2014    595
# 2015    136
# 2016     51
# 2017     11
# Name: mean_sales, dtype: int64

# %%
df_year = customers_info.groupby('cohort_year').count()['mean_sales']

ax = df_year.plot(kind='bar', alpha = 0.6, figsize = (9, 5))


rects = ax.patches
labels = df_year.values


for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(
        rect.get_x() + rect.get_width() / 2, height + 3, label, ha="center", va="bottom"
    )

ax.set_title('Количество новых клиентов за год')
ax.set_xlabel('Год когорты')
ax.set_ylim(top=650)
plt.show()

# %% [markdown]
# На данный момент еще не выяснили, как дела с оттоком, но с притоком новых клиентов точно что-то не так.
# **Приток новых клиентов падает с каждым годом.**

# %% [markdown]
# ## Retention

# %%
orders_info = orders.merge(customers_info, left_on = 'customer_id', right_on = 'id', how = 'left')
orders_info['order_date'] = pd.to_datetime(orders_info['order_date'])
orders_info['order_year'] = orders_info.order_date.dt.year
orders_info['order_month'] = orders_info.order_date.dt.strftime('%Y-%m')

# %%
orders_info.head()
# Out:
#      id_x order_date ship_mode customer_id    sales      id_y  \
# 0  100006 2014-09-07  Standard    DK-13375  377.970  DK-13375
# 1  100090 2014-07-08  Standard    EB-13705  699.192  EB-13705
# 2  100293 2014-03-14  Standard    NF-18475   91.056  NF-18475
# 3  100328 2014-01-28  Standard    JC-15340    3.928  JC-15340
# 4  100363 2014-04-08  Standard    JM-15655   21.376  JM-15655
#
#                name      segment       state         city min_order_date  \
# 0       Dennis Kane     Consumer        Ohio       Marion     2014-09-07
# 1        Ed Braxton    Corporate        Ohio        Akron     2014-07-08
# 2  Neil Franzosisch  Home Office    Illinois     Rockford     2014-03-14
# 3   Jasper Cacioppo     Consumer  California  Los Angeles     2014-01-28
# 4       Jim Mitchum    Corporate  New Jersey    Bridgeton     2014-04-08
#
#   max_order_date  mean_sales  count_sales cohort_month  cohort_year  \
# 0     2017-12-11  414.810750            8      2014-09         2014
# 1     2017-11-12  404.997556            9      2014-07         2014
# 2     2016-07-23   94.290500            4      2014-03         2014
# 3     2017-09-07   17.815750            4      2014-01         2014
# 4     2017-12-22  172.989400            5      2014-04         2014
#
#    order_year order_month
# 0        2014     2014-09
# 1        2014     2014-07
# 2        2014     2014-03
# 3        2014     2014-01
# 4        2014     2014-04

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
def cohort_column(df):
    df['cohort_period'] = np.arange(len(df))
    return df

# %%
df1 = orders_info.groupby(['cohort_year', 'order_year']).agg({'customer_id': 'nunique'})

# %%
cohort_column(df1)
# Out:
#                         customer_id  cohort_period
# cohort_year order_year
# 2014        2014                595              0
#             2015                437              1
#             2016                485              2
#             2017                517              3
# 2015        2015                136              4
#             2016                102              5
#             2017                120              6
# 2016        2016                 51              7
#             2017                 45              8
# 2017        2017                 11              9

# %%
df1.groupby(level=0).apply(cohort_column).reset_index().set_index(['cohort_year', 'cohort_period'])
# Out:
# <ipython-input-62-09f106e5479a>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df1.groupby(level=0).apply(cohort_column).reset_index().set_index(['cohort_year', 'cohort_period'])
#                            order_year  customer_id
# cohort_year cohort_period
# 2014        0                    2014          595
#             1                    2015          437
#             2                    2016          485
#             3                    2017          517
# 2015        0                    2015          136
#             1                    2016          102
#             2                    2017          120
# 2016        0                    2016           51
#             1                    2017           45
# 2017        0                    2017           11

# %% [markdown]
# **Реализация оконной функции row_number()**
#
# Код ниже является аналогом SQL выражения
#
# `row_number() over (partition by cohort_year order by order_year)`

# %%
orders_year = (orders_info
                  .groupby(['cohort_year', 'order_year']).agg({'customer_id': 'nunique'})
                  .groupby(level=0).apply(cohort_column)
                  .rename(columns = {'customer_id': 'unique_customers'})
                  .reset_index()
                  .set_index(['cohort_year', 'cohort_period'])
              )
orders_year
# Out:
# <ipython-input-63-f64b563f99f0>:3: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   .groupby(level=0).apply(cohort_column)
#                            order_year  unique_customers
# cohort_year cohort_period
# 2014        0                    2014               595
#             1                    2015               437
#             2                    2016               485
#             3                    2017               517
# 2015        0                    2015               136
#             1                    2016               102
#             2                    2017               120
# 2016        0                    2016                51
#             1                    2017                45
# 2017        0                    2017                11

# %% [markdown]
# Обращение по мультииндексу

# %%
# orders_year.loc[(2014, 0)]
# Out:
# order_year          2014
# unique_customers     595
# Name: (2014, 0), dtype: int64

# %%
cohort_group_size = orders_year['unique_customers'].groupby(level=0).first()
cohort_group_size
# Out:
# cohort_year
# 2014    595
# 2015    136
# 2016     51
# 2017     11
# Name: unique_customers, dtype: int64

# %%
orders_year['unique_customers'].unstack(1)
# Out:
# cohort_period      0      1      2      3
# cohort_year
# 2014           595.0  437.0  485.0  517.0
# 2015           136.0  102.0  120.0    NaN
# 2016            51.0   45.0    NaN    NaN
# 2017            11.0    NaN    NaN    NaN

# %%
user_retention = orders_year['unique_customers'].unstack(0).divide(cohort_group_size, axis=1)
user_retention.T
# Out:
# cohort_period    0         1         2         3
# cohort_year
# 2014           1.0  0.734454  0.815126  0.868908
# 2015           1.0  0.750000  0.882353       NaN
# 2016           1.0  0.882353       NaN       NaN
# 2017           1.0       NaN       NaN       NaN

# %%
sns.set(style='white')
plt.figure(figsize=(10, 6))
plt.title('Удержание клиентов по когортам')
sns.heatmap(user_retention.T, annot=True, fmt='.0%')
plt.show()

# %% [markdown]
# Аналогичная диаграмма с разбиением по месяцам бесполезна - в когортах 2016 и 2017 слишком мало людей. Но на основе этой диаграммы можно сделать вывод - в 2017 году не было проблем с оттоком клиентов, более того - старые клиенты стали совершать больше заказов.

# %% [markdown]
# **Средний чек по годам и когортам**

# %% [markdown]
# Посмотрим как менялся средний чек

# %%
orders_sales = (orders_info
                  .groupby(['cohort_year', 'order_year']).mean()['sales']
                  .to_frame()
                  .groupby(level=0).apply(cohort_column)
                  .reset_index()
                  .set_index(['cohort_year', 'cohort_period'])
               )

mean_sales = orders_sales['sales'].unstack(0).round(2)
orders_sales
# Out:
# <ipython-input-73-6dffc7dae636>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   .groupby(['cohort_year', 'order_year']).mean()['sales']
# <ipython-input-73-6dffc7dae636>:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   .groupby(level=0).apply(cohort_column)
#                            order_year       sales
# cohort_year cohort_period
# 2014        0                    2014  499.739420
#             1                    2015  452.470896
#             2                    2016  456.735345
#             3                    2017  427.103121
# 2015        0                    2015  456.227256
#             1                    2016  462.760809
#             2                    2017  449.735482
# 2016        0                    2016  526.957885
#             1                    2017  479.576838
# 2017        0                    2017  395.358158

# %%
mean_sales
# Out:
# cohort_year      2014    2015    2016    2017
# cohort_period
# 0              499.74  456.23  526.96  395.36
# 1              452.47  462.76  479.58     NaN
# 2              456.74  449.74     NaN     NaN
# 3              427.10     NaN     NaN     NaN

# %%
sns.set(style='white')
plt.figure(figsize=(10, 6))
plt.title('Средний чек по когортам')
sns.heatmap(mean_sales.T, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# В 2017 году средний чек уменьшился у всех когорт пользователей!

# %% [markdown]
# ## Выводы:

# %% [markdown]
# * **Отток клиентов не наблюдается** - наоборот, старые клиенты стали делать больше заказов.
#
# Следовательно, проблемы с доставкой не оказали существенного влияния на эти показатели.
#
# Однако, в ходе исследования обнаружились другие проблемы:
# * **Приток новых клиентов значительно падает** каждый год.
# * В данном году **средний чек снизился** по всем клиентам по сравнению с прошлыми годами.
#
# Скорее всего они не были вызваны проблемами с доставкой, необходимо искать причины в другом.
